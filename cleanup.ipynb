# %% [markdown]
# ## Clean up data
# #### Master data: NutrientValuees

# %%
import pandas as pd
import numpy

# %%
path = "data/raw_data/NutrientValues.xlsx"
path
# Out:
# 'data/raw_data/NutrientValues.xlsx'

# %%
df = pd.read_excel(path)
df.head()
# Out:
#    Food code           Main food description  WWEIA Category code  \
# 0   11000000                     Milk, human                 9602
# 1   11100000                       Milk, NFS                 1004
# 2   11111000                     Milk, whole                 1002
# 3   11111100         Milk, low sodium, whole                 1002
# 4   11111150  Milk, calcium fortified, whole                 1002
#
#   WWEIA Category description  Energy (kcal)  Protein (g)  Carbohydrate (g)  \
# 0                 Human milk             70         1.03              6.89
# 1          Milk, reduced fat             51         3.27              4.85
# 2                Milk, whole             61         3.15              4.80
# 3                Milk, whole             61         3.10              4.46
# 4                Milk, whole             61         3.15              4.80
#
#    Sugars, total (g)  Fiber, total dietary (g)  Total Fat (g)  ...  Iron (mg)  \
# 0               6.89                       0.0           4.38  ...       0.03
# 1               5.08                       0.0           2.04  ...       0.03
# 2               5.05                       0.0           3.25  ...       0.03
# 3               4.46                       0.0           3.46  ...       0.05
# 4               5.05                       0.0           3.25  ...       0.03
#
#    Zinc (mg)  Copper (mg)  Selenium (mcg)  Potassium (mg)  Sodium (mg)  \
# 0       0.17        0.052             1.8              51           17
# 1       0.42        0.014             3.1             141           45
# 2       0.37        0.025             3.7             132           43
# 3       0.38        0.010             2.0             253            3
# 4       0.37        0.025             3.7             132           43
#
#    Caffeine (mg)  Theobromine (mg)  Alcohol (g)  Water (g)
# 0              0                 0          0.0      87.50
# 1              0                 0          0.0      89.13
# 2              0                 0          0.0      88.13
# 3              0                 0          0.0      88.20
# 4              0                 0          0.0      88.13
#
# [5 rows x 50 columns]

# %% [markdown]
# #### Data count

# %%
df.count()
# Out:
# Food code                                 8690
# Main food description                     8690
# WWEIA Category code                       8690
# WWEIA Category description                8690
# Energy (kcal)                             8690
# Protein (g)                               8690
# Carbohydrate (g)                          8690
# Sugars, total (g)                         8690
# Fiber, total dietary (g)                  8690
# Total Fat (g)                             8690
# Fatty acids, total saturated (g)          8690
# Fatty acids, total monounsaturated (g)    8690
# Fatty acids, total polyunsaturated (g)    8690
# Cholesterol (mg)                          8690
# Retinol (mcg)                             8690
# Vitamin A, RAE (mcg_RAE)                  8690
# Carotene, alpha (mcg)                     8690
# Carotene, beta (mcg)                      8690
# Cryptoxanthin, beta (mcg)                 8690
# Lycopene (mcg)                            8690
# Lutein + zeaxanthin (mcg)                 8690
# Thiamin (mg)                              8690
# Riboflavin (mg)                           8690
# Niacin (mg)                               8690
# Vitamin B-6 (mg)                          8690
# Folic acid (mcg)                          8690
# Folate, food (mcg)                        8690
# Folate, DFE (mcg_DFE)                     8690
# Folate, total (mcg)                       8690
# Choline, total (mg)                       8690
# Vitamin B-12 (mcg)                        8690
# Vitamin B-12, added (mcg)                 8690
# Vitamin C (mg)                            8690
# Vitamin D (D2 + D3) (mcg)                 8690
# Vitamin E (alpha-tocopherol) (mg)         8690
# Vitamin E, added (mg)                     8690
# Vitamin K (phylloquinone) (mcg)           8690
# Calcium (mg)                              8690
# Phosphorus (mg)                           8690
# Magnesium (mg)                            8690
# Iron (mg)                                 8690
# Zinc (mg)                                 8690
# Copper (mg)                               8690
# Selenium (mcg)                            8690
# Potassium (mg)                            8690
# Sodium (mg)                               8690
# Caffeine (mg)                             8690
# Theobromine (mg)                          8690
# Alcohol (g)                               8690
# Water (g)                                 8690
# dtype: int64

# %%
def format_columns(df):
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    return df

format_columns(df)
df.head()
# Out:
#    food_code           main_food_description  wweia_category_code  \
# 0   11000000                     Milk, human                 9602
# 1   11100000                       Milk, NFS                 1004
# 2   11111000                     Milk, whole                 1002
# 3   11111100         Milk, low sodium, whole                 1002
# 4   11111150  Milk, calcium fortified, whole                 1002
#
#   wweia_category_description  energy_kcal  protein_g  carbohydrate_g  \
# 0                 Human milk           70       1.03            6.89
# 1          Milk, reduced fat           51       3.27            4.85
# 2                Milk, whole           61       3.15            4.80
# 3                Milk, whole           61       3.10            4.46
# 4                Milk, whole           61       3.15            4.80
#
#    sugars,_total_g  fiber,_total_dietary_g  total_fat_g  ...  iron_mg  \
# 0             6.89                     0.0         4.38  ...     0.03
# 1             5.08                     0.0         2.04  ...     0.03
# 2             5.05                     0.0         3.25  ...     0.03
# 3             4.46                     0.0         3.46  ...     0.05
# 4             5.05                     0.0         3.25  ...     0.03
#
#    zinc_mg  copper_mg  selenium_mcg  potassium_mg  sodium_mg  caffeine_mg  \
# 0     0.17      0.052           1.8            51         17            0
# 1     0.42      0.014           3.1           141         45            0
# 2     0.37      0.025           3.7           132         43            0
# 3     0.38      0.010           2.0           253          3            0
# 4     0.37      0.025           3.7           132         43            0
#
#    theobromine_mg  alcohol_g  water_g
# 0               0        0.0    87.50
# 1               0        0.0    89.13
# 2               0        0.0    88.13
# 3               0        0.0    88.20
# 4               0        0.0    88.13
#
# [5 rows x 50 columns]

# %% [markdown]
# #### Drop any columns and rows that are NaN

# %%
df = df.dropna()
df.count()
# Out:
# food_code                               8690
# main_food_description                   8690
# wweia_category_code                     8690
# wweia_category_description              8690
# energy_kcal                             8690
# protein_g                               8690
# carbohydrate_g                          8690
# sugars,_total_g                         8690
# fiber,_total_dietary_g                  8690
# total_fat_g                             8690
# fatty_acids,_total_saturated_g          8690
# fatty_acids,_total_monounsaturated_g    8690
# fatty_acids,_total_polyunsaturated_g    8690
# cholesterol_mg                          8690
# retinol_mcg                             8690
# vitamin_a,_rae_mcg_rae                  8690
# carotene,_alpha_mcg                     8690
# carotene,_beta_mcg                      8690
# cryptoxanthin,_beta_mcg                 8690
# lycopene_mcg                            8690
# lutein_+_zeaxanthin_mcg                 8690
# thiamin_mg                              8690
# riboflavin_mg                           8690
# niacin_mg                               8690
# vitamin_b-6_mg                          8690
# folic_acid_mcg                          8690
# folate,_food_mcg                        8690
# folate,_dfe_mcg_dfe                     8690
# folate,_total_mcg                       8690
# choline,_total_mg                       8690
# vitamin_b-12_mcg                        8690
# vitamin_b-12,_added_mcg                 8690
# vitamin_c_mg                            8690
# vitamin_d_d2_+_d3_mcg                   8690
# vitamin_e_alpha-tocopherol_mg           8690
# vitamin_e,_added_mg                     8690
# vitamin_k_phylloquinone_mcg             8690
# calcium_mg                              8690
# phosphorus_mg                           8690
# magnesium_mg                            8690
# iron_mg                                 8690
# zinc_mg                                 8690
# copper_mg                               8690
# selenium_mcg                            8690
# potassium_mg                            8690
# sodium_mg                               8690
# caffeine_mg                             8690
# theobromine_mg                          8690
# alcohol_g                               8690
# water_g                                 8690
# dtype: int64

# %%
df.to_csv('data/formatted_data/NutrientValues.csv')

# %% [markdown]
# #### PortionsAndWeights

# %%
path_2 = 'data/raw_data/PortionsAndWeights.xlsx'

# %%
df2 = pd.read_excel(path_2)
df2.head()
# Out:
#    Food code Main food description  Subcode Subcode description  \
# 0   11000000           Milk, human      NaN                 NaN
# 1   11000000           Milk, human      NaN                 NaN
# 2   11000000           Milk, human      NaN                 NaN
# 3   11100000             Milk, NFS      NaN                 NaN
# 4   11100000             Milk, NFS      NaN                 NaN
#
#    WWEIA Category code WWEIA Category description  Seq num  \
# 0                 9602                 Human milk        1
# 1                 9602                 Human milk        2
# 2                 9602                 Human milk        3
# 3                 1004          Milk, reduced fat        1
# 4                 1004          Milk, reduced fat        2
#
#       Portion description  Portion weight (g)
# 0                   1 cup               246.0
# 1  Quantity not specified                 0.0
# 2                 1 fl oz                30.8
# 3                   1 cup               244.0
# 4                 1 fl oz                30.5

# %%
format_columns(df2)
df2.head()
# Out:
#    food_code main_food_description  subcode subcode_description  \
# 0   11000000           Milk, human      NaN                 NaN
# 1   11000000           Milk, human      NaN                 NaN
# 2   11000000           Milk, human      NaN                 NaN
# 3   11100000             Milk, NFS      NaN                 NaN
# 4   11100000             Milk, NFS      NaN                 NaN
#
#    wweia_category_code wweia_category_description  seq_num  \
# 0                 9602                 Human milk        1
# 1                 9602                 Human milk        2
# 2                 9602                 Human milk        3
# 3                 1004          Milk, reduced fat        1
# 4                 1004          Milk, reduced fat        2
#
#       portion_description  portion_weight_g
# 0                   1 cup             246.0
# 1  Quantity not specified               0.0
# 2                 1 fl oz              30.8
# 3                   1 cup             244.0
# 4                 1 fl oz              30.5

# %% [markdown]
# #### Drop any columns and rows that are NaN

# %%
df2 = df2.dropna()
df2.head()
# Out:
#        food_code                         main_food_description    subcode  \
# 18467   53108200  Snack cake, chocolate, with icing or filling  1000231.0
# 18468   53108200  Snack cake, chocolate, with icing or filling  1000242.0
# 18469   53108200  Snack cake, chocolate, with icing or filling  1000276.0
# 18470   53108200  Snack cake, chocolate, with icing or filling  1000277.0
# 18471   53108200  Snack cake, chocolate, with icing or filling  1000325.0
#
#                 subcode_description  wweia_category_code  \
# 18467  Tastykake chocolate cupcakes                 5502
# 18468      Little Debbie Swiss Roll                 5502
# 18469                       Ho Ho's                 5502
# 18470                    Ding Dongs                 5502
# 18471                Oreo Cakesters                 5502
#
#       wweia_category_description  seq_num portion_description  \
# 18467             Cakes and pies        1           1 cupcake
# 18468             Cakes and pies        1           1 cupcake
# 18469             Cakes and pies        1             1 Ho Ho
# 18470             Cakes and pies        1         1 Ding Dong
# 18471             Cakes and pies        1        1 snack cake
#
#        portion_weight_g
# 18467              32.0
# 18468              40.0
# 18469              28.0
# 18470              40.0
# 18471              28.0

# %%
df2.count()
# Out:
# food_code                     848
# main_food_description         848
# subcode                       848
# subcode_description           848
# wweia_category_code           848
# wweia_category_description    848
# seq_num                       848
# portion_description           848
# portion_weight_g              848
# dtype: int64

# %%
df2.to_csv('data/formatted_data/PortionsAndWeights.csv')
